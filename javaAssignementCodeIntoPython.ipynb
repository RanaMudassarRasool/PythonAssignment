# %% [markdown]
# <a href="https://colab.research.google.com/github/ranamaddy/PythonAssignment/blob/main/javaAssignementCodeIntoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Suppose you work as a software developer for a software solutions company. Your project manager tasked you with designing and developing an Insurance Management System for one of your company's clients. In the development of the system, the object-oriented approach must be implemented. Moreover, the system must meet the minimum requirements listed below:
#  No 1  One (1) abstract superclass
# No2 One (1) interface
# N0 3 At least three (3) subclasses
# No 3.1 Requirement Fields with proper data types at least four (4) fields for the superclass •
# No 3.2 at least three (3) fields for other classes or subclasses)
# No 5 User-defined Methods with proper return types and scope
# No 5.1 at least two (2) abstract methods in the abstract class
# No 5.2  use at least one (1) built-in method from the Math or String classes
# No 6 at least two (2) user-defined methods for each subclass
# No 7 two (2) interface methods with calculations/transactions
# No 8 Application of the concept of encapsulation
# No 9 Application of at least one (1) method overriding and one (1) method overloading
# No 10 Comments that describe the purpose of blocks of code
# No 11 Program must run without errors .
#  code in java
# /*
#  * To change this license header, choose License Headers in Project Properties.
#  * To change this template file, choose Tools | Templates
#  * and open the template in the editor.
#  */
# package javaapplication1;
#
# // No 1 - Abstract superclass
# abstract class Insurance {
#     // 3.1 - Fields for superclass
#     protected String policyNumber;
#     protected String policyHolderName;
#     protected double policyAmount;
#
#     // 5.1 - Abstract methods
#     abstract void calculatePremium();
#     abstract void printPolicy();
# }
#
# // No 2 - Interface
# interface Transaction {
#     void deposit(double amount);
#     void withdraw(double amount);
# }
#
# // No 3 - Subclasses
# // 3.2 Subclass
#  class HealthInsurance extends Insurance {
#     // 3.2 Fields for subclass
#     private int policyHolderAge;
#     private String policyHolderGender;
#     private boolean smoker;
#
#     // 5. User-defined methods
#     public void calculatePremium() {
#         policyAmount = policyAmount * 0.03;
#     }
#     public void printPolicy() {
#         System.out.println("Health Insurance Policy");
#     }
#     public void setPolicyHolderAge(int policyHolderAge) {
#         this.policyHolderAge = policyHolderAge;
#     }
#     public void setPolicyHolderGender(String policyHolderGender) {
#         this.policyHolderGender = policyHolderGender;
#     }
#     public void setSmoker(boolean smoker) {
#         this.smoker = smoker;
#     }
# }
#
# // 3.2 Subclass
#
# class CarInsurance extends Insurance {
#     // 3.2 Fields for subclass
#     private String carModel;
#     private String carMake;
#     private int carYear;
#
#     // 5. User-defined methods
#     public void calculatePremium() {
#         policyAmount = policyAmount * 0.05;
#     }
#     public void printPolicy() {
#         System.out.println("Car Insurance Policy");
#     }
#     public void setCarModel(String carModel) {
#         this.carModel = carModel;
#     }
#     public void setCarMake(String carMake) {
#         this.carMake = carMake;
#     }
#     public void setCarYear(int carYear) {
#         this.carYear = carYear;
#     }
# }
#
# // 3.2 Subclass
# class HomeInsurance extends Insurance {
#     // 3.2 Fields for subclass
#     private String propertyType;
#     private String propertyAddress;
#     private double propertyValue;
#
#     // 5. User-defined methods
#     public void calculatePremium() {
#         policyAmount = policyAmount * 0.02;
#     }
#     public void printPolicy() {
#         System.out.println("Home Insurance Policy");
#     }
#     public void setPropertyType(String propertyType) {
#         this.propertyType = propertyType;
#     }
#     public void setPropertyAddress(String propertyAddress) {
#         this.propertyAddress = propertyAddress;
#     }
#     public void setPropertyValue(double propertyValue) {
#         this.propertyValue = propertyValue;
#     }
# }
#
# // No 8 - Encapsulation
# class BankAccount implements Transaction {
#     private double balance = 0;
#
#     public void deposit(double amount) {
#         balance += amount;
#     }
#     public void withdraw(double amount) {
#         if (balance >= amount) {
#             balance -= amount;
#         } else {
#             System.out.println("Insufficient funds.");
#         }
#     }
# }
#
#
#
#
# public class JavaApplication1 {
#
#     /**
#      * @param args the command line arguments
#      */
#     public static void main(String[] args) {
#
#
#           // Create instances of each subclass
#     HealthInsurance healthPolicy = new HealthInsurance();
#     CarInsurance carPolicy = new CarInsurance();
#     HomeInsurance homePolicy = new HomeInsurance();
#
#     // Set policy information
#     healthPolicy.policyNumber = "HI1234";
#     healthPolicy.policyHolderName = "John Doe";
#     healthPolicy.policyAmount = 10000;
#     healthPolicy.setPolicyHolderAge(30);
#     healthPolicy.setPolicyHolderGender("Male");
#     healthPolicy.setSmoker(false);
#
#     carPolicy.policyNumber = "CI5678";
#     carPolicy.policyHolderName = "Jane Smith";
#     carPolicy.policyAmount = 5000;
#     carPolicy.setCarMake("Toyota");
#     carPolicy.setCarModel("Camry");
#     carPolicy.setCarYear(2015);
#
#     homePolicy.policyNumber = "HIJ910";
#     homePolicy.policyHolderName = "Bob Johnson";
#     homePolicy.policyAmount = 25000;
#     homePolicy.setPropertyType("Single Family Home");
#     homePolicy.setPropertyAddress("123 Main St.");
#     homePolicy.setPropertyValue(200000);
#
#     // Calculate premiums and print policies
#     healthPolicy.calculatePremium();
#     healthPolicy.printPolicy();
#     System.out.println("Policy Amount: " + healthPolicy.policyAmount);
#
#     carPolicy.calculatePremium();
#     carPolicy.printPolicy();
#     System.out.println("Policy Amount: " + carPolicy.policyAmount);
#
#     homePolicy.calculatePremium();
#     homePolicy.printPolicy();
#    System.out.println("Policy Amount: " + homePolicy.policyAmount);
#
#
#     }
#
# }

# %%
from abc import ABC, abstractmethod

# No 1 - Abstract superclass
class Insurance(ABC):
    # 3.1 - Fields for superclass
    def __init__(self):
        self.policyNumber = ""
        self.policyHolderName = ""
        self.policyAmount = 0.0

    # 5.1 - Abstract methods
    @abstractmethod
    def calculatePremium(self):
        pass

    @abstractmethod
    def printPolicy(self):
        pass

# No 2 - Interface
class Transaction:
    @abstractmethod
    def deposit(self, amount):
        pass

    @abstractmethod
    def withdraw(self, amount):
        pass

# No 3 - Subclasses
# 3.2 Subclass
class HealthInsurance(Insurance):
    # 3.2 Fields for subclass
    def __init__(self):
        super().__init__()
        self.policyHolderAge = 0
        self.policyHolderGender = ""
        self.smoker = False

    # 5. User-defined methods
    def calculatePremium(self):
        self.policyAmount *= 0.03

    def printPolicy(self):
        print("Health Insurance Policy")

    def setPolicyHolderAge(self, policyHolderAge):
        self.policyHolderAge = policyHolderAge

    def setPolicyHolderGender(self, policyHolderGender):
        self.policyHolderGender = policyHolderGender

    def setSmoker(self, smoker):
        self.smoker = smoker

# 3.2 Subclass
class CarInsurance(Insurance):
    # 3.2 Fields for subclass
    def __init__(self):
        super().__init__()
        self.carModel = ""
        self.carMake = ""
        self.carYear = 0

    # 5. User-defined methods
    def calculatePremium(self):
        self.policyAmount *= 0.05

    def printPolicy(self):
        print("Car Insurance Policy")

    def setCarModel(self, carModel):
        self.carModel = carModel

    def setCarMake(self, carMake):
        self.carMake = carMake

    def setCarYear(self, carYear):
        self.carYear = carYear

# 3.2 Subclass
class HomeInsurance(Insurance):
    # 3.2 Fields for subclass
    def __init__(self):
        super().__init__()
        self.propertyType = ""
        self.propertyAddress = ""
        self.propertyValue = 0.0

    # 5. User-defined methods
    def calculatePremium(self):
        self.policyAmount *= 0.02

    def printPolicy(self):
        print("Home Insurance Policy")

    def setPropertyType(self, propertyType):
        self.propertyType = propertyType

    def setPropertyAddress(self, propertyAddress):
        self.propertyAddress = propertyAddress

    def setPropertyValue(self, propertyValue):
        self.propertyValue = propertyValue

# No 8 - Encapsulation
class BankAccount(Transaction):
    def __init__(self):
        self.balance = 0.0

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            print("Insufficient funds.")

if __name__ == "__main__":
    # Create instances of each subclass
    healthPolicy = HealthInsurance()
    carPolicy = CarInsurance()
    homePolicy = HomeInsurance()
    # Set policy information
    healthPolicy.policyNumber = "HI1234"
    healthPolicy.policyHolderName = "John Doe"
    healthPolicy.policyAmount = 10000
    healthPolicy.setPolicyHolderAge(30)
    healthPolicy.setPolicyHolderGender("Male")
    healthPolicy.setSmoker(False)

    carPolicy.policyNumber = "CI5678"
    carPolicy.policyHolderName = "Jane Smith"
    carPolicy.policyAmount = 5000
    carPolicy.setCarMake("Toyota")
    carPolicy.setCarModel("Camry")
    carPolicy.setCarYear(2015)

    homePolicy.policyNumber = "HIJ910"
    homePolicy.policyHolderName = "Bob Johnson"
    homePolicy.policyAmount = 25000
    homePolicy.setPropertyType("Single Family Home")
    homePolicy.setPropertyAddress("123 Main St.")
    homePolicy.setPropertyValue(200000)

    # Calculate premiums and print policies
    healthPolicy.calculatePremium()
    healthPolicy.printPolicy()
    print("Policy Amount: " + str(healthPolicy.policyAmount))

    carPolicy.calculatePremium()
    carPolicy.printPolicy()
    print("Policy Amount: " + str(carPolicy.policyAmount))

    homePolicy.calculatePremium()
    homePolicy.printPolicy()
    print("Policy Amount: " + str(homePolicy.policyAmount))
# Out:
# Health Insurance Policy
# Policy Amount: 300.0
# Car Insurance Policy
# Policy Amount: 250.0
# Home Insurance Policy
# Policy Amount: 500.0
